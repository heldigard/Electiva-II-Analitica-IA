# %% [markdown]
# <a href="https://colab.research.google.com/github/heldigard/Electiva-Analitica-IA/blob/main/clases/Clase2-Analisis-Visualizacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 Clase 2: Análisis Exploratorio y Visualización de Datos
#
# ## Universidad UdeColombia - Especialización en Analítica de Datos
#
# ---
#
# ### 👋 ¡Bienvenidos a la Clase 2!
#
# En la clase anterior aprendiste a usar chatbots de IA para explorar datos. Hoy daremos el siguiente paso: **crear visualizaciones que cuenten historias** y **extraer insights de negocio**.
#
# ---
#
# ### ⏱️ Estructura de la Clase (3 horas)
#
# | Tiempo | Sección | Contenido | Tipo |
# |--------|---------|-----------|------|
# | 00:00 - 00:15 | 🎯 Introducción | Repaso Clase 1, Los 5 gráficos esenciales | Teoría |
# | 00:15 - 00:45 | 📊 Gráficos 1-3 | Histograma, Barras, Líneas | Demo + Práctica |
# | 00:45 - 01:10 | 📊 Gráficos 4-5 | Scatter Plot y Boxplot | Demo + Práctica |
# | 01:10 - 01:30 | 🎯 Decision Flow | Cómo elegir el gráfico correcto | Teoría |
# | **01:30 - 02:00** | **☕ DESCANSO** | **30 minutos** | |
# | 02:00 - 02:20 | 📖 Insight vs Observación | Framework de comunicación | Teoría + Ejercicio |
# | 02:20 - 02:50 | ✏️ **ACTIVIDAD CALIFICABLE 2** | 2 gráficos + insights (20% nota) | **Evaluación** |
# | 02:50 - 03:00 | 📝 Cierre | Resumen, recursos, intro Clase 3 | |
#
# > 💡 **Nota:** Los gráficos narrativos son contenido opcional para estudiantes avanzados.
#
# ---
#
# ### 🎯 Objetivos de esta clase
#
# Al finalizar esta sesión, serás capaz de:
#
# 1. **Dominar** los 5 tipos de gráficos estadísticos más importantes
# 2. **Interpretar** patrones, tendencias y outliers en los datos
# 3. **Extraer** insights de negocio a partir de visualizaciones
# 4. **Comunicar** hallazgos de forma clara y profesional
#
# ---

# %% [markdown]
# ## 📚 Los 5 Gráficos Esenciales para Análisis de Datos
#
# > 💡 **Memoriza esta tabla** — te servirá para decidir qué tipo de gráfico usar en cada situación.
#
# | # | Tipo de Gráfico | ¿Cuándo usarlo? | Ejemplo de pregunta |
# |---|-----------------|-----------------|--------------------|
# | 1 | **Histograma** | Distribución de UNA variable numérica | ¿Cómo se distribuyen los precios? |
# | 2 | **Barras** | Comparar categorías | ¿Qué categoría vende más? |
# | 3 | **Líneas** | Tendencias en el tiempo | ¿Cómo han evolucionado las ventas? |
# | 4 | **Dispersión (Scatter)** | Relación entre DOS variables | ¿Más precio = más calificación? |
# | 5 | **Boxplot** | Distribución y outliers | ¿Hay valores atípicos? |
#
# ---

# %% [markdown]
# ---
#
# ## 🎯 Decision Flow: ¿Qué Gráfico Usar y Cuándo?
#
# ⏱️ *Tiempo estimado: 10 minutos*
#
# ### El Decision Flow para Gráficos
#
# No todos los gráficos sirven para todas las preguntas. Usa este **decision flow** para elegir el gráfico correcto:
#
# ```
# ¿QUÉ TIPO DE PREGUNTA TIENES?
# │
# ├─ "¿Cómo se distribuyen los valores?"
# │   → HISTOGRAMA
# │   Ejemplo: ¿Cómo se distribuyen los precios de los productos?
# │
# ├─ "¿Qué categoría es mayor/menor?"
# │   → GRÁFICO DE BARRAS
# │   Ejemplo: ¿Qué categoría de productos vende más?
# │
# ├─ "¿Cómo cambió algo en el tiempo?"
# │   → GRÁFICO DE LÍNEAS
# │   Ejemplo: ¿Cómo han evolucionado las ventas mensuales?
# │
# ├─ "¿Hay relación entre X e Y?"
# │   → SCATTER PLOT
# │   Ejemplo: ¿Más precio = mejor calificación?
# │
# └─ "¿Hay valores atípicos?"
#     → BOXPLOT
#     Ejemplo: ¿Hay productos con precios extremos?
# ```
#
# ### 📊 Decision Flow Detallado
#
# | Tu Pregunta | Variable X | Variable Y | Gráfico Recomendado |
# |-------------|------------|------------|---------------------|
# | ¿Cuál es la distribución de X? | Numérica | - | Histograma |
# | ¿Qué categoría de X tiene mayor Y? | Categórica | Numérica | Barras |
# | ¿Cómo cambió X en el tiempo? | Tiempo | Numérica | Líneas |
# | ¿X e Y están relacionados? | Numérica | Numérica | Scatter |
# | ¿Cuáles son los outliers de X por grupo? | Categórica | Numérica | Boxplot |
#
# ---
#
# ### ✅ Ejercicio: Elige el Gráfico Correcto
#
# Para cada pregunta de negocio, selecciona el gráfico apropiado:
#
# **Pregunta 1:** "¿Cuántos títulos hay en cada género de Netflix?"
# > **Respuesta:** Gráfico de Barras (comparar categorías)
#
# **Pregunta 2:** "¿Cómo ha cambiado la cantidad de contenido agregado a Netflix cada año?"
# > **Respuesta:** Gráfico de Líneas (tendencia temporal)
#
# **Pregunta 3:** "¿Los títulos más recientes tienden a tener calificaciones más altas?"
# > **Respuesta:** Scatter Plot (correlación año vs calificación)
#
# **Pregunta 4:** "¿Qué películas tienen duración inusualmente larga o corta?"
# > **Respuesta:** Boxplot (identificar outliers)
#
# **Pregunta 5:** "¿Cómo se distribuyen las duraciones de las películas?"
# > **Respuesta:** Histograma (distribución)
#
# > 💡 **Tip:** Antes de crear un gráfico, pregúntate: "¿Qué respuesta busco?" El gráfico debe ayudarte a encontrarla.
#
# ---

# %% [markdown]
# ## 🛠️ Configuración Inicial
#
# ⏱️ *Tiempo estimado: 5 minutos*

# %%
# Importar librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración de visualización
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = [10, 6]
plt.rcParams['font.size'] = 11

# Configuración de pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:,.2f}'.format)

print("✅ ¡Librerías cargadas correctamente!")

# %% [markdown]
# ## 📂 Cargar los Datasets
#
# Trabajaremos con **dos datasets** para practicar diferentes tipos de análisis:
#
# 1. **Netflix** - Para análisis categórico y temporal
# 2. **Retail Sales** - Para análisis numérico y de ventas

# %%
# Dataset 1: Netflix Movies & TV Shows
url_netflix = "https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/netflix_titles.csv"
df_netflix = pd.read_csv(url_netflix)
print(f"✅ Netflix: {df_netflix.shape[0]:,} títulos")

# Dataset 2: Retail Sales (Ventas minoristas)
url_retail = "https://raw.githubusercontent.com/datasets/retail-sales/main/data/retail-sales.csv"
df_retail = pd.read_csv(url_retail)
print(f"✅ Retail: {df_retail.shape[0]:,} registros")

# %%
# Vista rápida de Netflix
print("📺 Dataset Netflix:")
df_netflix.head(3)

# %%
# Vista rápida de Retail
print("🛒 Dataset Retail:")
df_retail.head(3)

# %% [markdown]
# ---
#
# ## 📊 GRÁFICO 1: Histograma
#
# ⏱️ *Tiempo estimado: 15 minutos*
#
# ### ¿Qué es?
# Un histograma muestra **cómo se distribuyen los valores** de una variable numérica. Divide los datos en "barras" (bins) y muestra cuántos valores caen en cada rango.
#
# ### ¿Cuándo usarlo?
# - Para entender la distribución de precios, edades, cantidades, etc.
# - Para identificar si los datos están concentrados o dispersos
# - Para detectar si hay múltiples "picos" (modas) en los datos
#
# > 💡 **Pregunta clave que responde:** "¿Cómo se distribuyen los valores de esta variable?"
#
# ### Ejemplo: Distribución de Años de Lanzamiento en Netflix

# %%
# Histograma de años de lanzamiento
plt.figure(figsize=(12, 5))

# Filtrar años recientes para mejor visualización
años_recientes = df_netflix[df_netflix['release_year'] >= 1990]['release_year']

plt.hist(años_recientes, bins=30, color='steelblue', edgecolor='white', alpha=0.7)

plt.title('📊 Distribución de Títulos por Año de Lanzamiento', fontsize=14, fontweight='bold')
plt.xlabel('Año de Lanzamiento')
plt.ylabel('Cantidad de Títulos')

# Agregar línea vertical en la mediana
mediana = años_recientes.median()
plt.axvline(x=mediana, color='red', linestyle='--', label=f'Mediana: {mediana:.0f}')
plt.legend()

plt.tight_layout()
plt.show()

print(f"\n📈 Estadísticas:")
print(f"   Año promedio: {años_recientes.mean():.1f}")
print(f"   Año mediano: {mediana:.0f}")
print(f"   Año mínimo: {años_recientes.min()}")
print(f"   Año máximo: {años_recientes.max()}")

# %% [markdown]
# ### 🎓 Interpretación del Histograma
#
# **Observaciones clave:**
# - La mayoría del contenido de Netflix es **reciente** (últimos 10 años)
# - Hay un crecimiento exponencial en producción de contenido
# - La distribución está **sesgada hacia la derecha** (hacia años recientes)
#
# **Insight de negocio:**
# > Netflix prioriza contenido nuevo. Esto sugiere que la plataforma invierte constantemente en producciones recientes para mantener el catálogo actualizado.

# %% [markdown]
# ### ✏️ ACTIVIDAD 1: Tu Histograma (10 min)
#
# Usa un chatbot para generar código que:
# 1. Extraiga la duración numérica de las películas (columna `duration` tiene valores como "90 min")
# 2. Cree un histograma de la duración de películas
# 3. Interprete: ¿Cuánto dura una película "típica" de Netflix?
#
# **Prompt sugerido:**
# ```
# Tengo un DataFrame 'df_netflix' con una columna 'duration' que tiene valores como:
# - '90 min' (para películas)
# - '2 Seasons' (para series)
#
# TAREA:
# 1. Filtra solo las películas (type == 'Movie')
# 2. Extrae el número de minutos de la columna duration
# 3. Crea un histograma de la duración en minutos
# 4. Agrega título y etiquetas claras
# ```

# %%
# 📝 PEGA AQUÍ TU CÓDIGO
# ========================

# %% [markdown]
# ---
#
# ## 📊 GRÁFICO 2: Gráfico de Barras
#
# ### ¿Qué es?
# Un gráfico de barras **compara cantidades entre diferentes categorías**. Cada barra representa una categoría y su altura representa el valor.
#
# ### ¿Cuándo usarlo?
# - Comparar ventas por categoría de producto
# - Comparar cantidad de empleados por departamento
# - Mostrar frecuencias de variables categóricas
#
# ### Ejemplo: Tipos de Contenido en Netflix

# %% [markdown]
# ---
#
# ## 🎯 Parte Extra: EJERCICIO - Insight vs. Observación
#
# ⏱️ *Tiempo estimado: 15 minutos*
#
# ### ¿Por qué este ejercicio?
#
# Mucha gente describe lo que ve en un gráfico, pero pocos extraen **insights de negocio**.
#
# > **La diferencia clave:**
# > - **Observación:** Describe lo que hay (hechos)
# > - **Insight:** Interpreta qué significa para el negocio (impacto, acción)
#
# ### Ejemplo Práctico
#
# Mira este ejemplo con un gráfico de ventas:
#
# ❌ **Observación** (poco útil):
# > "Las ventas subieron en Q4"
#
# ✅ **Insight** (valioso para el negocio):
# > "Las ventas aumentaron 45% en Q4, superando el promedio trimestral en 2.5x.
# > Esto sugiere que la campaña navideña fue 3x más efectiva que el promedio anual.
# > **Recomendación:** Duplicar inversión en campañas estacionales similares."
#
# ### 📊 Tu Turno
#
# Observa este gráfico a continuación (se creará con código Python).
#
# **Tu tarea:**
# 1. Mira el gráfico
# 2. Escribe una **observación** (lo que ves)
# 3. Escribe un **insight** (qué significa para el negocio)

# %%
# Crear un gráfico para practicar Insight vs. Observación

# Datos de ejemplo: Ventas mensuales de 2025
ventas_mensuales = pd.DataFrame({
    'mes': ['Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun', 
            'Jul', 'Ago', 'Sep', 'Oct', 'Nov', 'Dic'],
    'ventas': [120, 135, 128, 142, 138, 150, 145, 155, 165, 180, 280, 320],
    'meta': [140, 140, 140, 145, 145, 145, 150, 150, 150, 160, 200, 200]
})

# Crear gráfico
plt.figure(figsize=(12, 6))
plt.plot(ventas_mensuales['mes'], ventas_mensuales['ventas'], 
         marker='o', linewidth=2, markersize=8, label='Ventas Reales', color='steelblue')
plt.plot(ventas_mensuales['mes'], ventas_mensuales['meta'], 
         marker='s', linewidth=2, markersize=6, linestyle='--', 
         label='Meta Mensual', color='coral')

plt.title('📊 Ventas Mensuales 2025 vs. Meta', fontsize=14, fontweight='bold')
plt.xlabel('Mes')
plt.ylabel('Ventas (miles USD)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.ylim(0, 350)
plt.tight_layout()
plt.show()

# Mostrar los datos
print("Datos de ventas:")
print(ventas_mensuales)

# %% [markdown]
# ### ✅ Ejercicio: Escribe tu respuesta
#
# **Observación (lo que ves):**
# > [Escribe aquí - Describe el gráfico objetivamente]
#
# **Insight (qué significa para el negocio):**
# > [Escribe aquí - Interpreta: ¿Por qué pasa esto? ¿Qué implica? ¿Qué acción tomar?]
#
# ---
#
# ### 🎓 Desglosando un Buen Insight
#
# Un insight de negocio efectivo tiene:
#
# 1. **Evidencia numérica** específica (no "subió", sino "subió 45%")
# 2. **Contexto** de comparación (vs. promedio, vs. meta, vs. año anterior)
# 3. **Causa probable** de lo que sucede (la campaña funcionó, el mercado cambió, etc.)
# 4. **Recomendación accionable** (qué hacer basado en este insight)
#
# **Fórmula mágica:**
# ```
# [Número] + [Comparación] + [Causa] + [Acción]
# ```
#
# **Ejemplo:**
# ```
# Ventas de Q4 (280 + 320 = 600k)
# + superan Q1-Q3 promedio (145k)
# + en 4.1x
# + Causa: Campaña navideña y temporada de regalos
# + Acción: Duplicar inversión en Q4 2026
# ```
#
# ---
#
# ### 💡 Aplica esto en tus proyectos
#
# Cuando hagas el Taller Final, recuerda:
#
# ❌ **NO digas:** "El precio promedio es $50"
#
# ✅ **DI:** "El precio promedio de $50 está 20% por encima de la categoría,
# lo que sugiere un posicionamiento premium. Recomiendo análisis de
# elasticidad de precio para evaluar si aumentar precio reduciría volumen."
#
# **La diferencia es el valor que aportas como analista.**
#
# ---

# %%
# Gráfico de barras: Películas vs Series
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Gráfico 1: Conteo simple
conteo_tipo = df_netflix['type'].value_counts()
colores = ['#3498db', '#e74c3c']

axes[0].bar(conteo_tipo.index, conteo_tipo.values, color=colores, edgecolor='white')
axes[0].set_title('📺 Cantidad de Títulos por Tipo', fontsize=13, fontweight='bold')
axes[0].set_ylabel('Cantidad')

# Agregar etiquetas de valor
for i, v in enumerate(conteo_tipo.values):
    axes[0].text(i, v + 100, f'{v:,}', ha='center', fontweight='bold')

# Gráfico 2: Porcentaje
porcentaje = conteo_tipo / conteo_tipo.sum() * 100
axes[1].pie(porcentaje, labels=porcentaje.index, autopct='%1.1f%%', colors=colores, explode=[0.02, 0.02])
axes[1].set_title('📊 Distribución Porcentual', fontsize=13, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## 📖 Parte Extra: Gráfico Narrativo - Cuéntalo con una Historia
#
# ⏱️ *Tiempo estimado: 20 minutos*
#
# ### ¿Qué es un Gráfico Narrativo?
#
# Un gráfico narrativo es más que un gráfico bonito. **Cuenta una historia** con:
#
# 1. **Headline** - Título que comunica el insight principal
# 2. **Anotaciones** - Flechas y texto explicativos sobre puntos clave
# 3. **Key Takeaway** - 1 frase con el mensaje principal
# 4. **Call to Action** - Qué hacer basado en este insight
#
# ### 🎯 Por qué importa
#
# Los gráficos tradicionales muestran datos. Los gráficos narrativos **persuaden**.
#
# | Gráfico Tradicional | Gráfico Narrativo |
# |---------------------|-------------------|
# | "Ventas por mes" | "🎯 Q4 supera meta en 60% gracias a campaña navideña" |
# | Muestra datos | Cuenta una historia |
# | El lector interpreta | Tú guías la interpretación |
# | Pasivo | Activo y persuasivo |
#
# ### 📊 Ejemplo: Gráfico Narrativo de Categorías Netflix

# %%
# GRÁFICO NARRATIVO: Géneros en Netflix

# Preparar datos
generos = df['listed_in'].str.split(', ').explode()
top_generos = generos.value_counts().head(10)

# Crear figura
fig, ax = plt.subplots(figsize=(12, 7))

# Crear gráfico de barras horizontales
bars = ax.barh(range(len(top_generos)), top_generos.values, color='teal')

# ============ ELEMENTOS NARRATIVOS ============

# 1. HEADLINE - Título que comunica el insight
ax.set_title('🎯 Drama Internacional domina con 23% del catálogo Netflix',
          fontsize=16, fontweight='bold', pad=20)

# 2. ANOTACIONES - Flechas y texto explicativos
# Resaltar la barra #1 (Drama Internacional)
bars[0].set_color('#e74c3c')  # Rojo para destacar
ax.annotate('TOP 1\n+36% vs. #2',
            xy=(top_generos.values[0], 0),
            xytext=(top_generos.values[0] + 200, 0.5),
            fontsize=11, fontweight='bold',
            arrowprops=dict(facecolor='black', shrink=0.05, width=2, headwidth=8),
            color='#e74c3c')

# Resaltar Documentales (posición 4)
bars[3].set_color('#f39c12')  # Naranja para destacar
ax.annotate('Documentales\nen auge',
            xy=(top_generos.values[3], 3),
            xytext=(top_generos.values[3] + 150, 2.3),
            fontsize=10, fontweight='bold',
            arrowprops=dict(facecolor='black', shrink=0.05, width=2, headwidth=8),
            color='#f39c12')

# 3. KEY TAKEAWAY - Frase principal
plt.text(0.5, 0.92, 'Key Takeaway: El contenido internacional y dramático son el core business de Netflix',
         transform=fig.transFigure, fontsize=11, style='italic',
         ha='center', color='#2c3e50',
         bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.3))

# 4. CALL TO ACTION - Qué hacer
plt.text(0.5, 0.87, 'Action: Priorizar adquisiciones de Drama Internacional y Documentales para 2026',
         transform=fig.transFigure, fontsize=10, fontweight='bold',
         ha='center', color='#27ae60',
         bbox=dict(boxstyle='round', facecolor='lightgreen', alpha=0.4))

# Configuración adicional
ax.set_yticks(range(len(top_generos)))
ax.set_yticklabels(top_generos.index, fontsize=11)
ax.set_xlabel('Cantidad de Títulos', fontsize=12, fontweight='bold')
ax.invert_yaxis()  # Invertir para que el #1 quede arriba

# Eliminar bordes innecesarios
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout(rect=[0, 0, 1, 0.85])  # Ajustar para texto superior
plt.show()

# %% [markdown]
# ### 📖 Anatomía del Gráfico Narrativo
#
# Analiza cada elemento del gráfico anterior:
#
# **1. Headline (Título):**
# > ❌ "Géneros en Netflix" (aburrido, no dice nada)
# > ✅ "🎯 Drama Internacional domina con 23% del catálogo" (insight + número)
#
# **2. Anotaciones (Flechas):**
# > - La flecha roja resalta el género #1 y cuánto supera al #2
# > - La flecha naranja destaca Documentales como género en crecimiento
#
# **3. Key Takeaway:**
# > - Cuadro beige: "El contenido internacional y dramático son el core business"
# > - Resume la lección principal en 1 frase
#
# **4. Call to Action:**
# > - Cuadro verde: "Priorizar adquisiciones de Drama Internacional y Documentales"
# > - Acción específica basada en el insight
#
# ---
#
# ### 🎓 Cuándo Usar Gráficos Narrativos
#
# | Situación | Usa narrativo? | Por qué |
# |-----------|---------------|----------|
# | Exploración personal | ❌ No | Pierdes tiempo |
# | Presentación a equipo | ✅ Sí | Enseñas estructura |
# | Presentación a gerencia | ✅ Sí | **Persuasión crítica** |
# | Dashboard interactivo | ❌ No | Espacio limitado |
# | Reporte ejecutivo | ✅ Sí | Necesitas impacto |
#
# **Regla de oro:** Si vas a presentar a alguien que TOMA DECISIONES, usa narrativo.
#
# ---
#
# ### ✏️ Ejercicio Práctico
#
# **Tu desafío:** Toma uno de los gráficos que ya creaste y conviértelo en narrativo.
#
# Agrega:
# - Un headline con número clave
# - 1-2 anotaciones con flechas (plt.annotate())
# - Un key takeaway con plt.text()
# - Un call to action claro
#
# Usa la celda de abajo:

# %%
# Tu espacio para crear un gráfico narrativo
# Copia un gráfico anterior y agrega elementos narrativos

# Recuerda los 4 elementos:
# 1. Headline con número
# 2. Anotaciones con plt.annotate()
# 3. Key takeaway con plt.text()
# 4. Call to action claro

# Escribe tu código aquí:

# %% [markdown]
# ### Ejemplo Avanzado: Ratings por Tipo de Contenido

# %%
# Gráfico de barras agrupadas
# Top 6 ratings más comunes
top_ratings = df_netflix['rating'].value_counts().head(6).index.tolist()
df_filtrado = df_netflix[df_netflix['rating'].isin(top_ratings)]

# Crear tabla cruzada
tabla_cruzada = pd.crosstab(df_filtrado['rating'], df_filtrado['type'])

# Graficar
tabla_cruzada.plot(kind='bar', figsize=(12, 5), color=['#3498db', '#e74c3c'], edgecolor='white')

plt.title('📊 Clasificación de Contenido: Películas vs Series', fontsize=14, fontweight='bold')
plt.xlabel('Clasificación (Rating)')
plt.ylabel('Cantidad de Títulos')
plt.xticks(rotation=45)
plt.legend(title='Tipo')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🎓 Interpretación
#
# **Observaciones:**
# - TV-MA (contenido para adultos) domina en ambos tipos
# - Las series tienden a tener más clasificación TV-14
# - Las películas tienen más variedad de clasificaciones
#
# **Insight de negocio:**
# > Netflix se enfoca principalmente en audiencias adultas. El contenido familiar (TV-G, TV-Y) representa una porción menor del catálogo.

# %% [markdown]
# ---
#
# ## ☕ DESCANSO - 30 minutos
#
# **¡Excelente trabajo!** Ya dominamos los 2 primeros gráficos (Histograma y Barras).
#
# Tómate un café, estira las piernas, y regresamos para los 3 gráficos restantes.
#
# ---

# %% [markdown]
# ---
#
# ## 📊 GRÁFICO 3: Gráfico de Líneas
#
# ⏱️ *Tiempo estimado: 10 minutos*
#
# ### ¿Qué es?
# Un gráfico de líneas muestra **cómo cambia un valor a lo largo del tiempo**. Es perfecto para identificar tendencias y patrones temporales.
#
# ### ¿Cuándo usarlo?
# - Analizar ventas mensuales o anuales
# - Ver la evolución de métricas en el tiempo
# - Identificar estacionalidad
#
# > 💡 **Pregunta clave que responde:** "¿Cómo ha cambiado X en el tiempo?"
#
# ### Ejemplo: Crecimiento del Catálogo de Netflix

# %%
# Preparar datos: Contenido agregado por año
# Convertir date_added a datetime
df_netflix['date_added'] = pd.to_datetime(df_netflix['date_added'], errors='coerce')

# Extraer año de la fecha de adición
df_netflix['year_added'] = df_netflix['date_added'].dt.year

# Contar títulos agregados por año y tipo
agregados_por_año = df_netflix.groupby(['year_added', 'type']).size().unstack(fill_value=0)
agregados_por_año = agregados_por_año.dropna()

# Graficar
fig, ax = plt.subplots(figsize=(12, 6))

agregados_por_año.plot(kind='line', ax=ax, marker='o', linewidth=2, markersize=6)

plt.title('📈 Crecimiento del Catálogo de Netflix por Año', fontsize=14, fontweight='bold')
plt.xlabel('Año')
plt.ylabel('Títulos Agregados')
plt.legend(title='Tipo de Contenido')
plt.grid(True, alpha=0.3)

# Agregar anotación en el pico
max_year = agregados_por_año['Movie'].idxmax()
max_value = agregados_por_año.loc[max_year, 'Movie']
plt.annotate(f'Pico: {max_value:,.0f} películas', 
             xy=(max_year, max_value), 
             xytext=(max_year-2, max_value+200),
             arrowprops=dict(arrowstyle='->', color='gray'),
             fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🎓 Interpretación
#
# **Tendencias observadas:**
# - Netflix experimentó un crecimiento exponencial hasta ~2019
# - Hay una caída notable después de 2019-2020
# - Las películas siempre superan en cantidad a las series
#
# **Insight de negocio:**
# > La caída en contenido agregado puede deberse a: (1) Mayor enfoque en producciones originales de calidad, (2) Pérdida de licencias de estudios, (3) Cambio de estrategia post-pandemia.

# %% [markdown]
# ### ✏️ ACTIVIDAD 2: Análisis de Tendencias (15 min)
#
# Usa un chatbot para generar código que analice la **producción de contenido por país** a lo largo del tiempo.
#
# **Prompt sugerido:**
# ```
# Tengo un DataFrame 'df_netflix' con las columnas:
# - 'country': país de origen (ej: 'United States', 'India', 'United Kingdom')
# - 'year_added': año en que se agregó a Netflix
#
# TAREA:
# 1. Filtra los 5 países con más contenido
# 2. Agrupa por año y país
# 3. Crea un gráfico de líneas mostrando la evolución de cada país
# 4. Usa diferentes colores para cada país
# ```

# %%
# 📝 PEGA AQUÍ TU CÓDIGO
# ========================

# %% [markdown]
# ---
#
# ## 📊 GRÁFICO 4: Diagrama de Dispersión (Scatter Plot)
#
# ### ¿Qué es?
# Un scatter plot muestra la **relación entre dos variables numéricas**. Cada punto representa una observación con sus valores en ambas variables.
#
# ### ¿Cuándo usarlo?
# - Buscar correlaciones entre variables
# - ¿Más precio = más ventas? ¿Más horas = mejor calificación?
# - Identificar grupos o clusters
#
# ### Ejemplo: Año de Lanzamiento vs Duración de Películas

# %%
# Preparar datos: extraer duración de películas
peliculas = df_netflix[df_netflix['type'] == 'Movie'].copy()
peliculas['duracion_min'] = peliculas['duration'].str.extract('(\d+)').astype(float)

# Filtrar valores válidos
peliculas = peliculas.dropna(subset=['duracion_min', 'release_year'])
peliculas = peliculas[peliculas['release_year'] >= 1980]

# Crear scatter plot
plt.figure(figsize=(12, 6))

plt.scatter(peliculas['release_year'], peliculas['duracion_min'], 
            alpha=0.3, color='steelblue', s=20)

# Agregar línea de tendencia
z = np.polyfit(peliculas['release_year'], peliculas['duracion_min'], 1)
p = np.poly1d(z)
plt.plot(peliculas['release_year'].sort_values(), 
         p(peliculas['release_year'].sort_values()), 
         "r--", linewidth=2, label='Tendencia')

plt.title('📊 Relación: Año de Lanzamiento vs Duración de Películas', fontsize=14, fontweight='bold')
plt.xlabel('Año de Lanzamiento')
plt.ylabel('Duración (minutos)')
plt.legend()

# Agregar línea horizontal en 90 minutos (duración estándar)
plt.axhline(y=90, color='green', linestyle=':', alpha=0.7, label='90 min (estándar)')

plt.tight_layout()
plt.show()

# Calcular correlación
correlacion = peliculas['release_year'].corr(peliculas['duracion_min'])
print(f"\n📈 Correlación: {correlacion:.3f}")
print("   (Valores cercanos a 0 indican poca relación)")

# %% [markdown]
# ### 🎓 Interpretación
#
# **Observaciones:**
# - No hay una correlación fuerte entre año y duración
# - La mayoría de películas están entre 80-120 minutos
# - Hay más variabilidad en películas recientes
#
# **Insight:**
# > El formato de película de ~90 minutos se ha mantenido estable a lo largo de décadas. Las películas más largas (+150 min) son más comunes en años recientes.

# %% [markdown]
# ---
#
# ## 📊 GRÁFICO 5: Boxplot (Diagrama de Caja)
#
# ### ¿Qué es?
# Un boxplot muestra la **distribución de datos y sus valores atípicos (outliers)**. Muestra:
# - La mediana (línea central)
# - El rango intercuartílico (la caja)
# - Los valores extremos (bigotes)
# - Los outliers (puntos fuera de los bigotes)
#
# ### ¿Cuándo usarlo?
# - Comparar distribuciones entre grupos
# - Identificar valores atípicos
# - Ver si los datos están sesgados
#
# ### Ejemplo: Duración de Películas por Clasificación

# %%
# Preparar datos
top_ratings = ['TV-MA', 'TV-14', 'TV-PG', 'R', 'PG-13', 'PG']
peliculas_ratings = peliculas[peliculas['rating'].isin(top_ratings)].copy()

# Crear boxplot
plt.figure(figsize=(12, 6))

# Usar seaborn para un boxplot más atractivo
orden = peliculas_ratings.groupby('rating')['duracion_min'].median().sort_values(ascending=False).index

sns.boxplot(data=peliculas_ratings, x='rating', y='duracion_min', 
            order=orden, palette='viridis')

plt.title('📊 Distribución de Duración por Clasificación', fontsize=14, fontweight='bold')
plt.xlabel('Clasificación')
plt.ylabel('Duración (minutos)')

# Agregar línea de referencia
plt.axhline(y=90, color='red', linestyle='--', alpha=0.5, label='90 min')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🔍 Cómo Leer un Boxplot
#
# ```
#                     ┌─────────────────┐
#            Máximo ──│        │        │
#                     │   ┌────┴────┐   │
#               Q3 ───│   │         │   │── 75% de los datos
#                     │   │─────────│   │
#          Mediana ───│   │    ●    │   │── 50% (valor central)
#                     │   │─────────│   │
#               Q1 ───│   │         │   │── 25% de los datos
#                     │   └────┬────┘   │
#            Mínimo ──│        │        │
#                     └─────────────────┘
#               ●     ← Outliers (valores atípicos)
# ```

# %% [markdown]
# ### 🎓 Interpretación
#
# **Observaciones:**
# - Las películas con clasificación R (adultos) tienden a ser más largas
# - Contenido para niños (PG) tiende a ser más corto
# - Hay muchos outliers (películas muy largas) en todas las categorías
#
# **Insight de negocio:**
# > El contenido para adultos tiene más libertad creativa en duración, mientras que el contenido familiar se mantiene en duraciones más estándar, posiblemente considerando la atención de los niños.

# %% [markdown]
# ---
#
# ## ✏️ ACTIVIDAD 3: Análisis Completo (20 min)
#
# ### El Reto:
#
# Imagina que trabajas para Netflix y te piden analizar el contenido **por país**.
#
# **Preguntas a responder:**
#
# 1. ¿Cuáles son los 10 países que más contenido aportan a Netflix?
# 2. ¿Cómo se compara la proporción de películas vs series entre los top 5 países?
# 3. ¿Hay diferencias en la duración de películas entre países?
#
# ### Instrucciones:
#
# Usa chatbots para generar el código necesario. Para cada pregunta:
# 1. Crea un prompt claro
# 2. Genera y ejecuta el código
# 3. Escribe una interpretación

# %%
# PREGUNTA 1: Top 10 países por cantidad de contenido
# ===================================================

# %%
# PREGUNTA 2: Proporción películas vs series por país
# ===================================================

# %%
# PREGUNTA 3: Comparación de duración entre países (boxplot)
# ==========================================================

# %% [markdown]
# ### 📝 Tu Análisis:
#
# **Hallazgo 1 (Top países):**
# > [Tu interpretación]
#
# **Hallazgo 2 (Películas vs Series):**
# > [Tu interpretación]
#
# **Hallazgo 3 (Duración por país):**
# > [Tu interpretación]
#
# **Recomendación para Netflix:**
# > [Tu recomendación basada en los datos]

# %% [markdown]
# ---
#
# ## 🎨 BONUS: Gráficos Combinados
#
# Un análisis profesional a menudo requiere múltiples visualizaciones juntas.

# %%
# Dashboard resumen de Netflix
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. Tipo de contenido (Pie)
conteo_tipo = df_netflix['type'].value_counts()
axes[0, 0].pie(conteo_tipo, labels=conteo_tipo.index, autopct='%1.1f%%', 
               colors=['#3498db', '#e74c3c'], explode=[0.02, 0.02])
axes[0, 0].set_title('Tipo de Contenido', fontsize=12, fontweight='bold')

# 2. Top 5 géneros (Barras horizontales)
generos = df_netflix['listed_in'].str.split(', ').explode().value_counts().head(5)
axes[0, 1].barh(generos.index, generos.values, color='teal')
axes[0, 1].set_title('Top 5 Géneros', fontsize=12, fontweight='bold')
axes[0, 1].invert_yaxis()

# 3. Evolución temporal (Líneas)
agregados = df_netflix.groupby('year_added').size()
agregados = agregados.dropna()
axes[1, 0].plot(agregados.index, agregados.values, marker='o', color='purple', linewidth=2)
axes[1, 0].set_title('Contenido Agregado por Año', fontsize=12, fontweight='bold')
axes[1, 0].set_xlabel('Año')
axes[1, 0].grid(True, alpha=0.3)

# 4. Distribución de clasificaciones (Barras)
ratings = df_netflix['rating'].value_counts().head(6)
axes[1, 1].bar(ratings.index, ratings.values, color='coral')
axes[1, 1].set_title('Top 6 Clasificaciones', fontsize=12, fontweight='bold')
axes[1, 1].tick_params(axis='x', rotation=45)

plt.suptitle('📊 Dashboard: Análisis del Catálogo de Netflix', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## 📚 Resumen de la Clase 2
#
# ### Los 5 Gráficos Esenciales:
#
# | Gráfico | Uso Principal | Pregunta que Responde |
# |---------|--------------|----------------------|
# | **Histograma** | Distribución | ¿Cómo se distribuyen los valores? |
# | **Barras** | Comparación | ¿Cuál categoría es mayor/menor? |
# | **Líneas** | Tendencias | ¿Cómo cambia en el tiempo? |
# | **Scatter** | Correlación | ¿Hay relación entre X e Y? |
# | **Boxplot** | Outliers | ¿Hay valores atípicos? |
#
# ### Proceso de Análisis:
#
# 1. **Observar** → ¿Qué muestra el gráfico?
# 2. **Interpretar** → ¿Qué significa esto?
# 3. **Contextualizar** → ¿Tiene sentido en el negocio?
# 4. **Recomendar** → ¿Qué acción sugiere?
#
# ### ⚠️ Recuerda:
# > Un gráfico sin interpretación es solo una imagen bonita. El valor está en el **insight**.
#
# ---
#
# ### 🚀 Próxima Clase:
# **Clase 3: Proyecto Integrador - APIs y Análisis Completo**
# - Conexión a APIs externas
# - Análisis de datos de e-commerce
# - Presentación de resultados ejecutivos

# %% [markdown]
# ---
#
# ## 📖 Recursos Adicionales del Curso
#
# Para profundizar en los temas de esta clase, consulta estos documentos complementarios:
#
# | Recurso | Descripción | Cuándo usarlo |
# |---------|-------------|---------------|
# | **[Business-Question-Canvas.md](Business-Question-Canvas.md)** | Plantilla para estructurar preguntas de negocio | Antes de crear visualizaciones |
# | **[AI-Reliability-Checklist.md](AI-Reliability-Checklist.md)** | Checklist para verificar respuestas de IA | Al validar gráficos generados |
# | **[Prompt-Playbook.md](Prompt-Playbook.md)** | Plantillas reutilizables de prompts | Para solicitar gráficos específicos |
# | **[Prompt-Templates-2026.md](Prompt-Templates-2026.md)** | Prompts avanzados categorizados | Para análisis complejos |
# | **[Data-Ethics-Guide.md](Data-Ethics-Guide.md)** | Guía de ética en manejo de datos | Siempre con datos sensibles |
#
# > 💡 **Tip:** Usa el Business Question Canvas antes de crear cada visualización para asegurar que responda una pregunta de negocio real.
#
# ---
#
# ## ✅ Actividad Calificable 2 (20% de la nota final)
#
# ### Instrucciones:
#
# Esta actividad se completa durante la clase y cuenta para tu nota final.
#
# **Tarea:** Usando el dataset de Netflix y las técnicas de visualización aprendidas:
#
# 1. **Gráfico 1 - Análisis Categórico (10 pts):**
#    - Crea un gráfico de barras que responda: "¿Cuáles son los 5 países que más contenido aportan a Netflix?"
#    - Usa el Decision Flow para justificar tu elección de gráfico
#    - Escribe un **insight de negocio** (no solo una observación)
#    - Formato del insight: [Número] + [Comparación] + [Causa probable] + [Acción recomendada]
#
# 2. **Gráfico 2 - Análisis Temporal o de Distribución (10 pts):**
#    - Elige una de estas preguntas:
#      - "¿Cómo ha evolucionado el contenido agregado a Netflix por año?"
#      - "¿Cómo se distribuyen las duraciones de las películas?"
#    - Crea el gráfico apropiado según el Decision Flow
#    - Escribe un **insight de negocio** usando el framework Observación vs. Insight
#
# **Tiempo:** 25 minutos durante la clase
# **Entregable:** 2 gráficos ejecutados + insight de negocio por cada uno
